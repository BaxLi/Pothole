# %% [markdown]
# <a href="https://colab.research.google.com/github/BaxLi/Pothole/blob/master/PotholeProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import os
# очистка ОЗУ
import gc

# %%
# %cd /content/
# !mkdir yolo8_pothole
# %cd /content/yolo8_pothole
# !mkdir dataset
# Out:
# /content
# /content/yolo8_pothole

# %%
# !cp "/content/drive/MyDrive/AI-University/sample_data/Pothole/pothole_dataset_v8/pothole_dataset_v8.zip" "/content/yolo8_pothole"

# %%
# !cp   "/content/yolo8_pothole/runs" "/content/drive/MyDrive/AI-University/sample_data/Pothole"
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-26-bedd9d6f1502> in <module>
# ----> 1 get_ipython().system('cp   "/content/yolo8_pothole/runs" "/content/drive/MyDrive/AI-University/sample_data/Pothole"')
#
# /usr/local/lib/python3.8/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      93       kwargs.update({'also_return_output': True})
#      94
# ---> 95     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      96
#      97     if pip_warn:
#
# /usr/local/lib/python3.8/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     434   # is expected to call this function, thus adding one level of nesting to the
#     435   # stack.
# --> 436   result = _run_command(
#     437       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
# ...

# %%
# file_path = "/content/drive/MyDrive/AI-University/sample_data/Pothole/pothole_dataset_v8/pothole_dataset_v8.zip"
# target_dir = "/content/yolo8_pothole/"

# os.system(f"cp '{file_path}' '{target_dir}'")

# %%
import zipfile

with zipfile.ZipFile("/content/yolo8_pothole/pothole_dataset_v8.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/yolo8_pothole/dataset")

# %%
# import shutil
# # shutil.copytree('/content/drive/MyDrive/AI-University/sample_data/Pothole/pothole_dataset_v8', '/content/yolo8_pothole_dataset')
# shutil.copytree('/content/yolo8_pothole/runs', '/content/drive/MyDrive/AI-University/sample_data/Pothole/runs')
# Out:
# '/content/drive/MyDrive/AI-University/sample_data/Pothole/runs'

# %%
datasetPath='/content/yolo8_pothole/dataset/pothole_dataset_v8'
gDrivePath='/content/drive/MyDrive/AI-University/sample_data/Pothole/pothole_dataset_v8'
datasetYAMLFile=os.path.join(datasetPath, 'pothole.yaml')

# %% [markdown]
# ## Загрузка REPO

# %%
# Скачиваем репозиторию и её зависимости
# !pip install ultralytics -qU
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.43 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.8/78.2 GB disk)

# %% [markdown]
# ## Обучаем нейросеть

# %%
gc.collect()
# Out:
# 4

# %%
from ultralytics import YOLO
# Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
# model = YOLO("/content/runs/detect/yolov8n_v8_TEST2/weights/best.pt")  # load a custom model
# model = YOLO("/content/runs/detect/yolov8n_v8_TEST2/weights/last.pt")  # load a custom model
# Out:
# ...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]

# %%
results = model.train(data=datasetYAMLFile, imgsz=640, epochs=25, batch=32, name='yolov8n_v8_POTHOLE')  # Обучаем модель
# Out:
# Ultralytics YOLOv8.0.43 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %% [markdown]
# ## Предиктим

# %%
image=os.path.join(datasetPath,'valid/images/G0011195.jpg') # + pothole
image=os.path.join(gDrivePath,'TEST/MD-1.jpg')
# image=os.path.join(gDrivePath,'TEST/t1.jpg')
image=os.path.join(gDrivePath,'TEST/g1.jpg') # + pothole
# image=os.path.join(gDrivePath,'TEST/G0011969.jpg') # no pothole

# %%
# Выполняем код детекции
res = model(image)  #Предиктим
# Out:
# image 1/1 /content/drive/MyDrive/AI-University/sample_data/Pothole/pothole_dataset_v8/TEST/g1.jpg: 384x640 1 pothole, 20.1ms
# Speed: 0.7ms preprocess, 20.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
print(res[0].boxes.boxes)
# Out:
# tensor([[7.72000e+02, 6.38000e+02, 8.18000e+02, 6.50000e+02, 3.00004e-01, 0.00000e+00]], device='cuda:0')

# %%
from google.colab.patches import cv2_imshow
res_plotted = res[0].plot()
cv2_imshow(res_plotted)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F30A8061880>

# %% [markdown]
# ### Plot bounding boxes

# %%
def box_label(image, box, label='', color=(128, 128, 128), txt_color=(255, 255, 255)):
  lw = max(round(sum(image.shape) / 2 * 0.003), 2)
  p1, p2 = (int(box[0]), int(box[1])), (int(box[2]), int(box[3]))
  cv2.rectangle(image, p1, p2, color, thickness=lw, lineType=cv2.LINE_AA)
  if label:
    tf = max(lw - 1, 1)  # font thickness
    w, h = cv2.getTextSize(label, 0, fontScale=lw / 3, thickness=tf)[0]  # text width, height
    outside = p1[1] - h >= 3
    p2 = p1[0] + w, p1[1] - h - 3 if outside else p1[1] + h + 3
    cv2.rectangle(image, p1, p2, color, -1, cv2.LINE_AA)  # filled
    cv2.putText(image,
                label, (p1[0], p1[1] - 2 if outside else p1[1] + h + 2),
                0,
                lw / 3,
                txt_color,
                thickness=tf,
                lineType=cv2.LINE_AA)

# %%
def plot_bboxes(image, boxes, labels=[], colors=[], score=True, conf=None):
  #Define COCO Labels
  if labels == []:
    labels = {0: u'__background__', 1: u'person', 2: u'bicycle',3: u'car', 4: u'motorcycle', 5: u'airplane', 6: u'bus', 7: u'train', 8: u'truck', 9: u'boat', 10: u'traffic light', 11: u'fire hydrant', 12: u'stop sign', 13: u'parking meter', 14: u'bench', 15: u'bird', 16: u'cat', 17: u'dog', 18: u'horse', 19: u'sheep', 20: u'cow', 21: u'elephant', 22: u'bear', 23: u'zebra', 24: u'giraffe', 25: u'backpack', 26: u'umbrella', 27: u'handbag', 28: u'tie', 29: u'suitcase', 30: u'frisbee', 31: u'skis', 32: u'snowboard', 33: u'sports ball', 34: u'kite', 35: u'baseball bat', 36: u'baseball glove', 37: u'skateboard', 38: u'surfboard', 39: u'tennis racket', 40: u'bottle', 41: u'wine glass', 42: u'cup', 43: u'fork', 44: u'knife', 45: u'spoon', 46: u'bowl', 47: u'banana', 48: u'apple', 49: u'sandwich', 50: u'orange', 51: u'broccoli', 52: u'carrot', 53: u'hot dog', 54: u'pizza', 55: u'donut', 
(218, 130, 77),(164, 102, 79),(43, 152, 125),(185, 124, 151),(95, 159, 238),(128, 89, 85),(228, 6, 60),(6, 41, 210),(11, 1, 133),(30, 96, 58),(230, 136, 109),(126, 45, 174),(164, 63, 165),(32, 111, 29),(232, 40, 70),(55, 31, 198),(148, 211, 129),(10, 186, 211),(181, 201, 94),(55, 35, 92),(129, 140, 233),(70, 250, 116),(61, 209, 152),(216, 21, 138),(100, 0, 176),(3, 42, 70),(151, 13, 44),(216, 102, 88),(125, 216, 93),(171, 236, 47),(253, 127, 103),(205, 137, 244),(193, 137, 224),(36, 152, 214),(17, 50, 238),(154, 165, 67),(114, 129, 60),(119, 24, 48),(73, 8, 110)]
  
  #plot each boxes
  for box in boxes:
    #add score in label if score=True
    if score :
      label = labels[int(box[-1])+1] + " " + str(round(100 * float(box[-2]),1)) + "%"
    else :
      label = labels[int(box[-1])+1]
    #filter every box under conf threshold if conf threshold setted
    if conf :
      if box[-2] > conf:
        color = colors[int(box[-1])]
        box_label(image, box, label, color)
    else:
      color = colors[int(box[-1])]
      box_label(image, box, label, color)

  #show image
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

  try:
    import google.colab
    IN_COLAB = True
  except:
    IN_COLAB = False

  if IN_COLAB:
    cv2_imshow(image) #if used in Colab
  else :
    cv2.imshow(image) #if used in Python

# %% [markdown]
# ### lets show some examples

# %%
plot_bboxes(image, res[0].boxes.boxes, conf=0.8)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-54-a711dddfc394> in <module>
# ----> 1 plot_bboxes(image, res[0].boxes.boxes, conf=0.8)
#
# <ipython-input-50-c7e5fa84923e> in plot_bboxes(image, boxes, labels, colors, score, conf)
#      25
#      26   #show image
# ---> 27   image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      28
#      29   try:
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %% [markdown]
# ## Выводим разметку на изображении

# %%
import PIL

# Функция, которая отображает предсказания YOLO-модели
# На вход нужно подать путь к изображению, и аутпут нейронной сети
# П.С. - если вы работаете не в колабе, можно вывести результат, указав аргумент show=True в model.predict()
colors_list = ["red", "green", "blue"]
def show_predict(image_path, result):
    result = result[0].boxes.data
    image = PIL.Image.open(image_path)
    draw_image = PIL.ImageDraw.Draw(image)
    for i in range(result.shape[0]):
        class_index = int(result[i, -1].detach().item())
        draw_image.rectangle(result[i, :4].detach().numpy(), outline=colors_list[class_index], width=5)
    return image

# %%
show_predict(os.path.join(datasetPath,'valid/images/G0011195.jpg'), res)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-d1a4a606e1d0> in <module>
# ----> 1 show_predict(os.path.join(datasetPath,'valid/images/G0011195.jpg'), res)
#
# <ipython-input-21-3661095c7bd3> in show_predict(image_path, result)
#      11     for i in range(result.shape[0]):
#      12         class_index = int(result[i, -1].detach().item())
# ---> 13         draw_image.rectangle(result[i, :4].detach().numpy(), outline=colors_list[class_index], width=5)
#      14     return image
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
